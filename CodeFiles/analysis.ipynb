# %% [markdown]
# # Greeting DS Montenegro!
# #

# %%
print(f"Hi there, {input('please input your name: ')}!")

# %% [markdown]
# - Question: How many records are in our sample below?

# %%
rows = [4,7,9,12]

len(rows)

# %%
name = input('Enter a name:')

print(f'The name is:',name)

number_of_characters_in_name = len(name)
print(f'# Characters in the name:',number_of_characters_in_name)

print (f'Spelled out:')
for index, letter in enumerate(name):
    print(f'Character #:',index+1,letter)
